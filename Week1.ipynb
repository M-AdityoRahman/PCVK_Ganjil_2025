# %% [markdown]
# <a href="https://colab.research.google.com/github/M-AdityoRahman/PCVK_Ganjil_2025/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
from matplotlib import pyplot as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://i.pinimg.com/736x/5e/35/7e/5e357eb1a2f608b1dcff9dc8cacd0047.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg"]

# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
    image = io.imread(url)    # read image
    image = cv.resize(image, (0, 0), fx=0.5, fy=0.5) # resize image to half size
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) # convert color to RGB
    final_frame = cv.hconcat((image, image_2))    # concatenate image
    cv2_imshow(final_frame)    # show image
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=736x654>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = " ,tinggi, " x " ,lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_3 = image_2.copy()
for y in range(lebar):
    image_3[int(tinggi/2), y] = [255, 255, 255]

final_frame = cv.hconcat([image_2, image_3])
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# **Pertanyaan**

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#
# Karena Google Colab menyediakan lingkungan berbasis cloud yang gratis, tidak memerlukan instalasi, mendukung GPU, dan memudahkan kolaborasi.

# %% [markdown]
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# numpy: Manipulasi array
#
# pandas: Analisis data
#
# cv2: Pemrosesan gambar
#
# skimage: Pemrosesan gambar
#
# PIL: Manipulasi gambar
#
# matplotlib: Visualisasi data
# Tidak semua wajib digunakan, tergantung kebutuhan

# %% [markdown]
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut : image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
# Untuk memperkecil gambar menjadi setengah ukuran aslinya. Jika tidak dilakukan, gambar akan tetap berukuran besar.

# %% [markdown]
# 4. Perhatikan potongan kode progam berikut :
#
#
#     for y in range(lebar):
#         image_3[int(tinggi/2), y] = [255, 255, 255]
#
#   Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# Nilai RGB untuk warna putih. Digunakan untuk mengubah warna pixel menjadi putih.

# %% [markdown]
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# Resolusi adalah jumlah pixel (lebar × tinggi). Semakin tinggi resolusi, semakin detail gambarnya.

# %% [markdown]
# **TUGAS**

# %%
# Garis vertikal di tengah
image_4 = image_2.copy()
for x in range(tinggi):
    image_4[x, int(lebar/2)] = [255, 255, 255]

# Garis diagonal dari kiri atas ke kanan bawah
image_5 = image_2.copy()
for i in range(min(tinggi, lebar)):
    image_5[i, i] = [255, 255, 255]
for i in range(min(tinggi, lebar)):
    image_5[i, lebar - 1 - i] = [255, 255, 255]

final_frame = cv.hconcat([image_4, image_5])
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_6 = image_2.copy()
start_y = int(lebar * 0.25)
end_y = int(lebar * 0.75)
for y in range(start_y, end_y):
    image_6[int(tinggi/2), y] = [255, 255, 255]

cv2_imshow(image_6)
# Out:
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_7 = image_2.copy()
start_x, start_y = 100, 150
size = 100
for x in range(start_x, start_x + size):
    for y in range(start_y, start_y + size):
        image_7[x, y] = [255, 255, 255]

cv2_imshow(image_7)
# Out:
# <PIL.Image.Image image mode=RGB size=400x286>
